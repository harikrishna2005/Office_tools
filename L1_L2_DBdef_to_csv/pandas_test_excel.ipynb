# %%
import pandas as pd

excel_file_path = r"D:\A7985\Hari\Work\Projects\Blue Lake\VS code\onedrivefoldercreated\table_generation\DB項目定義書（L1_APP_DCS）dcs_v1.0.xlsx"
my_sheet_name = 'APRS_FLIGHT'


df = pd.read_excel(excel_file_path, sheet_name=my_sheet_name, header=None)
df

# %%
# column_names = ['A','B','C','D','E','F','G']
column_names = ['col_jp_logical_name','col_en_logical_name','col_physical_name','col_datatype','col_size','col_pk_key','col_description']


numeric_mask = pd.to_numeric(df[0], errors='coerce').notna()
column_structure_df = df[[1,2,3,5,6,7,14]][numeric_mask]

column_structure_df.columns = column_names
physical_name= 'B1_OW_DCS_CM_APRS_FLIGHT_TXN'
# column_structure_df['H'] = 'B1_OW_DCS_CM_APRS_FLIGHT_TXN'
column_structure_df.insert(0,'H','B1_OW_DCS_CM_APRS_FLIGHT_TXN')
column_structure_df.insert(1,'table_jp_logical_name','DCSCM CONSTRAINT COMPUTER-ASSISTED PASSENGER PRE-SCREENING SYSTEM DETAILS')
column_structure_df['col_ignored']=0

column_structure_df

# %%
import openpyxl
import pandas as pd



def get_all_sheets(excel_file_path):
    workbook = openpyxl.load_workbook(excel_file_path)
    # Get all sheet names
    sheet_names = workbook.sheetnames
    return sheet_names


def get_valid_sheets(excel_file_path, index_sheet=None):
    all_sheets = get_all_sheets(excel_file_path)

    # index sheet existence
    if index_sheet not in all_sheets or index_sheet is None:
        raise ValueError(f"{index_sheet} not found in the list. so CANNOT PROCEED.")
        # all_sheets.remove(index_sheet)
    
    all_sheets.remove(index_sheet)
    return all_sheets

def get_tablenames_columnnames_in_dataframe_from_single_sheet(excel_file_path, mysheet_name):
    df_excel = pd.read_excel(excel_file_path, sheet_name=mysheet_name, header=None)

    # =========Get table name details=========
    table_en_logical_name = df_excel[5][4]
    table_jp_logical_name = df_excel[5][3]
    table_physical_name = df_excel[5][1]
    # print(f'{table_jp_logical_name},{table_en_logical_name},{table_physical_name}')



    # =======Get column Details in a data frame ========
    


    numeric_mask = pd.to_numeric(df_excel[0], errors='coerce').notna()
    # column_names = ['col_jp_logical_name','col_en_logical_name','col_physical_name','col_datatype','col_size','col_pk_key','col_description']
    # column_structure_df = df_excel[[1,2,3,5,6,7,14]][numeric_mask]
    column_names = ['col_jp_logical_name','col_en_logical_name','col_physical_name','col_datatype','col_size','col_pk_key']
    column_structure_df = df_excel[[1,2,3,5,6,7]][numeric_mask]


    column_structure_df.columns = column_names

    # =======append table name details to column details ==========
    column_structure_df.insert(0,'table_physical_name',table_physical_name)
    column_structure_df.insert(1,'table_en_logical_name',table_en_logical_name)
    column_structure_df.insert(2,'table_jp_logical_name',table_jp_logical_name)
    column_structure_df['col_ignored']=0

    return column_structure_df
    
def load_df_to_csv(sheet_data_frame, csv_file_path: str, header_csv: bool=False):
    
    # print(csv_file_path)    
    sheet_data_frame.to_csv(csv_file_path, mode='a',encoding='UTF-8', header=header_csv, index=False)

    


  
    



    
def start(excel_file_path,index_sheet,csv_path):
    list_of_sheets = get_valid_sheets(excel_file_path,index_sheet)
    
    # INITIALIZE THE CSV FILE
    with open(csv_path, 'w'):
        pass  # This just opens and immediately closes the file, effectively truncating it
    
    # start processing each sheet 
    print('******* STARTED PROCESSING ************')
    first_time_only_header:bool = True
    for mysheet in list_of_sheets:
        sheet_data_frame = get_tablenames_columnnames_in_dataframe_from_single_sheet(excel_file_path,mysheet)
        load_df_to_csv(sheet_data_frame,csv_path,first_time_only_header)

        if first_time_only_header:
            first_time_only_header = False


        print(f'Completed processing for sheet ==>     {mysheet}')
        # for loop ends here
    print(f'\n  Loaded data  :     {csv_path}')
    print("******* PROCESSING COMPLETED ************")
    

# excel_file_path = r"D:\Bluelake_02\REQUIREMENTS\23.DB定義書 (DB Definition)\DB項目定義書（L1_APP_DCS）dcs_v1.0.xlsx"
# index_sheet = 'TABLE_OF_CONTENTS'
# csv_path = r"D:\A7985\Hari\Work\Projects\Blue Lake\VS code\L1_db_table_data.csv"

excel_file_path = r"D:\Bluelake_02\REQUIREMENTS\23.DB定義書 (DB Definition)\DB項目定義書（L2_APP_DCS）dcs_v1.0.xlsx"
index_sheet = '目次'
csv_path = r"D:\A7985\Hari\Work\Projects\Blue Lake\VS code\L2_db_table_data.csv"

start(excel_file_path=excel_file_path,
      index_sheet=index_sheet,
      csv_path=csv_path)
# Out:
# ******* STARTED PROCESSING ************
# Completed processing for sheet ==>     APRS_FLIGHT
# Completed processing for sheet ==>     APRS_PRODUCT_DETAILS
# Completed processing for sheet ==>     APRS_PRODUCT
# Completed processing for sheet ==>     BAG_BAGGAGE_GRP_ERR_FREETEXT
# Completed processing for sheet ==>     BAG_BAGGAGE_GROUP_ERROR
# Completed processing for sheet ==>     BAG_BAGGAGE_GROUP_ITINERARY
# Completed processing for sheet ==>     BAG_BAGGAGE_GROUP_LINK
# Completed processing for sheet ==>     BAG_BAGGAGE_GROUP
# Completed processing for sheet ==>     BAG_BAGGAGE_ITINERARY_LINK
# Completed processing for sheet ==>     BAG_BAGGAGE
# Completed processing for sheet ==>     BAG_FLIGHT_LEG
# Completed processing for sheet ==>     BAG_FLIGHT_SPECIAL_BAGGAGE
# Completed processing for sheet ==>     BAG_FLIGHT
# Completed processing for sheet ==>     BAG_POOL_BAGGAGE_MEMBER
# Completed processing for sheet ==>     BAG_XSB_CITYPAIR_ALLOWANCE
# Completed processing for sheet ==>     BAG_XSB_CITYPAIR_ITEM_ATTRIBUTE
# Completed processing for sheet ==>     BAG_XSB_CITYPAIR_ITEM
# Completed processing for sheet ==>     BAG_XSB_CITYPAIR
# Completed processing for sheet ==>     BAG_XSB_FEE_STATUS
# Completed processing for sheet ==>     BAG_XSB_FEE
# Completed processing for sheet ==>     BAG_XSB_GROUP
# Completed processing for sheet ==>     BAG_XSB_ITINERARY_LINK
# Completed processing for sheet ==>     FILE_HEADER
# Completed processing for sheet ==>     HIST_ASSOCIATION_GROUP
# Completed processing for sheet ==>     HIST_HISTORY_DETAILS
# Completed processing for sheet ==>     HIST_HISTORY
# Completed processing for sheet ==>     PAX_ACCOUNT_PROVIDER
# Completed processing for sheet ==>     PAX_ADDRESS
# Completed processing for sheet ==>     PAX_APM_CONTACT_DETAILS
# Completed processing for sheet ==>     PAX_APN_CONTACT_DETAILS
# Completed processing for sheet ==>     PAX_BAGGAGE_ERROR_FREETEXT
# Completed processing for sheet ==>     PAX_BAGGAGE_ERROR
# Completed processing for sheet ==>     PAX_BAGGAGE_FLIGHT_LEG
# Completed processing for sheet ==>     PAX_BAGGAGE_FLIGHT_SPECIAL_BAGG
# Completed processing for sheet ==>     PAX_BAGGAGE_FLIGHT
# Completed processing for sheet ==>     PAX_BAGGAGE_GROUP_BAGGAGE_LINK
# Completed processing for sheet ==>     PAX_BAGGAGE_GRP_ERR_FREETEXT
# Completed processing for sheet ==>     PAX_BAGGAGE_GROUP_ERROR
# Completed processing for sheet ==>     PAX_BAGGAGE_GROUP_ITINERARY
# Completed processing for sheet ==>     PAX_BAG_GRP_MEMBERS_OF_POOL
# Completed processing for sheet ==>     PAX_BAGGAGE_GROUP
# Completed processing for sheet ==>     PAX_BAGGAGE_ITINERARY_LINK
# Completed processing for sheet ==>     PAX_BAGGAGE
# Completed processing for sheet ==>     PAX_CDT_ERROR_FREETEXT
# Completed processing for sheet ==>     PAX_CDT_ERROR
# Completed processing for sheet ==>     PAX_CDT_ITINERARY_ERR_FREETEXT
# Completed processing for sheet ==>     PAX_CDT_ITINERARY_ERROR
# Completed processing for sheet ==>     PAX_CDT
# Completed processing for sheet ==>     PAX_DID_LINK
# Completed processing for sheet ==>     PAX_EMERGENCY_CONTACT
# Completed processing for sheet ==>     PAX_FLIGHT_CHANGE_DETAILES
# Completed processing for sheet ==>     PAX_FLIGHT_CHANGE
# Completed processing for sheet ==>     PAX_FOID
# Completed processing for sheet ==>     PAX_FQTV
# Completed processing for sheet ==>     PAX_ITINERARY_ADC_MESSAGE
# Completed processing for sheet ==>     PAX_ITINERARY_ADC_RLOC_LINK
# Completed processing for sheet ==>     PAX_ITINERARY_ADDRESS
# Completed processing for sheet ==>     PAX_ITINERARY_COMPENSATION_ATTR
# Completed processing for sheet ==>     PAX_ITINERARY_COMPENSATION_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_COMPENSATION_AUTH
# Completed processing for sheet ==>     PAX_ITINERARY_COMPENSATION
# Completed processing for sheet ==>     PAX_ITINERARY_CORPORATE
# Completed processing for sheet ==>     PAX_ITINERARY_CREDIT_CARD
# Completed processing for sheet ==>     PAX_ITINERARY_EMD
# Completed processing for sheet ==>     PAX_ITINERARY_FLT_BANNER_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_FLT_DISRUPT_COMM
# Completed processing for sheet ==>     PAX_ITINERARY_FLT_DISRUPT_REAS
# Completed processing for sheet ==>     PAX_ITINERARY_FLT_DISRUPTION
# Completed processing for sheet ==>     PAX_ITINERARY_FLT_STATUS
# Completed processing for sheet ==>     PAX_ITINERARY_FQTV
# Completed processing for sheet ==>     PAX_ITINERARY_FREETEXT
# Completed processing for sheet ==>     PAX_ITINERARY_IAPP_DETAILES
# Completed processing for sheet ==>     PAX_ITINERARY_IAPP
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_ADC_MESSAGE
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_ADC_RLOC_LINK
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_CANDIDATE_TKT
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_COMMENT
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_CONFORMANCE
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_CON_COMM_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_CON_COMMENT
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_LOST_SEAT
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_LOST_SERVICE
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_LOUNGE_FACILI
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_LOUNGE
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_OTHER_MONEY
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_SEAT
# Completed processing for sheet ==>     PAX_ITINERARY_LEG_SERVICE_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_LEG
# Completed processing for sheet ==>     PAX_ITINERARY_NON_TRAVELER
# Completed processing for sheet ==>     PAX_ITINERARY_OSI_AMOUNT
# Completed processing for sheet ==>     PAX_ITINERARY_OSI_FREETEXT
# Completed processing for sheet ==>     PAX_ITINERARY_OSI
# Completed processing for sheet ==>     PAX_ITINERARY_OSI_WARNING_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_OSI_WARNING
# Completed processing for sheet ==>     PAX_ITINERARY_OAL_LEG_DETAILS
# Completed processing for sheet ==>     PAX_ITINERARY_OAL_LEG
# Completed processing for sheet ==>     PAX_ITINERARY_OAL_TICKET
# Completed processing for sheet ==>     PAX_ITINERARY_REG_DOC_PER_QTY
# Completed processing for sheet ==>     PAX_ITINERARY_REGULATORY_DOC
# Completed processing for sheet ==>     PAX_ITINERARY_REVENUE_INTEGRITY
# Completed processing for sheet ==>     PAX_ITINERARY_RLOC
# Completed processing for sheet ==>     PAX_ITINERARY_SK_AMOUNT
# Completed processing for sheet ==>     PAX_ITINERARY_SK_FREETEXT
# Completed processing for sheet ==>     PAX_ITINERARY_SK
# Completed processing for sheet ==>     PAX_ITINERARY_SK_WARNING_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_SK_WARNING
# Completed processing for sheet ==>     PAX_ITINERARY_SSR_AMOUNT
# Completed processing for sheet ==>     PAX_ITINERARY_SSR_FREETEXT
# Completed processing for sheet ==>     PAX_ITINERARY_SSR
# Completed processing for sheet ==>     PAX_ITINERARY_SSR_WARNING_FREE
# Completed processing for sheet ==>     PAX_ITINERARY_SSR_WARNING
# Completed processing for sheet ==>     PAX_ITINERARY_STAFF
# Completed processing for sheet ==>     PAX_ITINERARY
# Completed processing for sheet ==>     PAX_ITINERARY_TKT
# Completed processing for sheet ==>     PAX_ITINERARY_TRANSIT_FREETEXT
# Completed processing for sheet ==>     PAX_ITINERARY_TRANSIT
# Completed processing for sheet ==>     PAX_ITINERARY_TYPE
# Completed processing for sheet ==>     PAX_ITINERARY_VOUCHER_DISR_FLT
# Completed processing for sheet ==>     PAX_ITINERARY_VOUCHER_REPL_FLT
# Completed processing for sheet ==>     PAX_ITINERARY_VOUCHER
# Completed processing for sheet ==>     PAX_OSI_FREETEXT
# Completed processing for sheet ==>     PAX_OSI
# Completed processing for sheet ==>     PAX_OTHER_DETAILS
# Completed processing for sheet ==>     PAX_REGULATORY_DOC_PERMIT_QUA
# Completed processing for sheet ==>     PAX_REGULATORY_DOC
# Completed processing for sheet ==>     PAX_SK_FREETEXT
# Completed processing for sheet ==>     PAX_SK
# Completed processing for sheet ==>     PAX_SSR_FREETEXT
# Completed processing for sheet ==>     PAX_SSR
# Completed processing for sheet ==>     PAX_STAFF
# Completed processing for sheet ==>     PAX_STATUS
# Completed processing for sheet ==>     PAX
# Completed processing for sheet ==>     PAX_UCI_LINK
# Completed processing for sheet ==>     PAX_UPI_LINK
# Completed processing for sheet ==>     SEAT_CODESHARE_DETAILS
# Completed processing for sheet ==>     SEAT_COLUMN_DETAILS
# Completed processing for sheet ==>     SEAT_COMPARTMENT_CLASS_AREA
# Completed processing for sheet ==>     SEAT_COMPARTMENT_CLASS_CONFIG
# Completed processing for sheet ==>     SEAT_COMPARTMENT_CLASS
# Completed processing for sheet ==>     SEAT_CURTAIN_ZONE
# Completed processing for sheet ==>     SEAT_CUSTOMER
# Completed processing for sheet ==>     SEAT_SEAT_ATTRIBUTE
# Completed processing for sheet ==>     SEAT_SEAT_BLOCK
# Completed processing for sheet ==>     SEAT_SEAT_ITINERARY_LINK
# Completed processing for sheet ==>     SEAT_SEAT_SALEABLE_CONFIG
# Completed processing for sheet ==>     SEAT_SEATMAP
# Completed processing for sheet ==>     SEAT_SSR_DETAILS
# Completed processing for sheet ==>     SEAT_SSR
#
#   Loaded data  :     D:\A7985\Hari\Work\Projects\Blue Lake\VS code\L1_db_table_data.csv
# ******* PROCESSING COMPLETED ************
